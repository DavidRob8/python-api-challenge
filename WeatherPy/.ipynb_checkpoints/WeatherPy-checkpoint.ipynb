# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---city_weather

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + weather_api_key + "&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    city_weather = requests.get(city_url).json()
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tobi village
# City not found. Skipping...
# Processing Record 2 of Set 1 | badger
# Processing Record 3 of Set 1 | kargasok
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | qaqortoq
# Processing Record 6 of Set 1 | sabang
# Processing Record 7 of Set 1 | anadyr
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | papatowai
# Processing Record 10 of Set 1 | lauro de freitas
# Processing Record 11 of Set 1 | ardmore
# Processing Record 12 of Set 1 | labrador city
# Processing Record 13 of Set 1 | saipan
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | turinsk
# Processing Record 16 of Set 1 | altay
# Processing Record 17 of Set 1 | flin flon
# Processing Record 18 of Set 1 | puerto natales
# Processing Record 19 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 1 | ust-nera
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          360
# Lat           360
# Lng           360
# Max Temp      360
# Humidity      360
# Cloudiness    360
# Wind Speed    360
# Country       360
# Date          360
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     badger  64.8000 -147.5333    -16.07        72         100        0.00
# 1   kargasok  59.0556   80.8572    -13.91        80         100       12.07
# 2  adamstown -25.0660 -130.1015     24.03        87          70        3.91
# 3   qaqortoq  60.7167  -46.0333      0.81        90         100        2.42
# 4     sabang   5.8933   95.3214     27.60        78          60        5.67
#
#   Country        Date
# 0      US  1704904679
# 1      RU  1704904844
# 2      PN  1704904461
# 3      GL  1704904847
# 4      ID  1704904370

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           badger  64.8000 -147.5333    -16.07        72         100
# 1         kargasok  59.0556   80.8572    -13.91        80         100
# 2        adamstown -25.0660 -130.1015     24.03        87          70
# 3         qaqortoq  60.7167  -46.0333      0.81        90         100
# 4           sabang   5.8933   95.3214     27.60        78          60
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      US  1704904679
# 1             12.07      RU  1704904844
# 2              3.91      PN  1704904461
# 3              2.42      GL  1704904847
# 4              5.67      ID  1704904370

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
city_data_df.sort_values(by='Date', ascending=False)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 359          chifeng  42.2683  118.9636     -6.33        76         100
# 358         holualoa  19.6228 -155.9522     19.91        94         100
# 357        quelimane -17.8786   36.8883     29.97        79          40
# 355      vilyuchinsk  52.9306  158.4028    -18.93        69         100
# 354      trincomalee   8.5711   81.2335     26.91        80         100
# ...              ...      ...       ...       ...       ...         ...
# 94          bilibino  68.0546  166.4372    -33.13        99          98
# 141          chonchi -42.6128  -73.8092     15.56        42           6
# 46            broome  42.2506  -75.8330      5.66        76         100
# 45           ushuaia -54.8000  -68.3000      9.79        53          75
# 60              hilo  19.7297 -155.0900     22.92        89          75
#
#          Wind Speed Country        Date
# City_ID
# 359            4.13      CN  1704905376
# ...

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'],
           edgecolors="black", alpha=.8)

# Incorporate the other graph properties
plt.grid()
plt.title("City Latitude vs Max Temperature (2024-01-10)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors="black", alpha=.8)

# Incorporate the other graph properties
plt.grid()
plt.title("City Latitude vs. Humidity (2022-01-10)")
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors="black", alpha=.8)

# Incorporate the other graph properties
plt.grid()
plt.title("City Latitude vs. Cloudiness (2022-01-10)")
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors="black", alpha=.8)

# Incorporate the other graph properties
plt.grid()
plt.title("City Latitude vs. Wind Speed (2022-01-10)")
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (m/s)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression(x_values, y_values, y_label,eq_x, eq_y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter (x_values, y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(eq_x,eq_y),fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    
    print(f"The r value is:{rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] > 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          badger  64.8000 -147.5333    -16.07        72         100
# 1        kargasok  59.0556   80.8572    -13.91        80         100
# 3        qaqortoq  60.7167  -46.0333      0.81        90         100
# 4          sabang   5.8933   95.3214     27.60        78          60
# 5          anadyr  64.7500  177.4833    -27.72        75           0
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      US  1704904679
# 1             12.07      RU  1704904844
# 3              2.42      GL  1704904847
# 4              5.67      ID  1704904370
# 5              4.00      RU  1704904850

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2               adamstown -25.0660 -130.1015     24.03        87          70
# 6               grytviken -54.2811  -36.5092      5.42        96         100
# 7               papatowai -46.5619  169.4708     15.12        72          75
# 8        lauro de freitas -12.8944  -38.3272     32.01        58          75
# 16         puerto natales -51.7236  -72.4875     13.25        58          75
#
#          Wind Speed Country        Date
# City_ID
# 2              3.91      PN  1704904461
# 6              1.53      GS  1704904528
# 7              2.35      NZ  1704904472
# 8              5.66      BR  1704904854
# 16             7.72      CL  1704904540

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], "Max Temperature(C)", 6, -30)
# Out:
# The r value is:-0.846218555677108

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], "Max Temperature(C)", -30, 10)
# Out:
# The r value is:0.6991207275134173

# %% [markdown]
# **Discussion about the linear relationship:** For cities in the Northern Hemisphere, the negative slope indicates that as the latitude increases, max temperature decreases. The absolute value of the r value is 0.85 (greater than 0.7), which indicates a strong negative linear relationship which means that as one variable increases (latitude), the other variable (max temperature) tends to decrease proportionally. For example, cities in the Northern Hemisphere right above the equator with latitudes close to 0, such as cities in Central America, will have a higher max temperatures then cities located in higher latitudes such as cities in Canada.
#
# For cities in the Southern Hemisphere, the positive slope indicates that as the latitude increases, max temperature increases. The absolute value of the r value is .70 (greater than or equal to 0.7) which indicates a strong positive linear relationship which means that as one variable increases (latitude), the other variable (max temperature) tends to increase proportionally. For example, cities in the Southern Hemisphere right below the equator with latitudes close to 0, such as cities in Ecuador, will have a higher max temperatures then cities located in lower latitudes such as cities in the lowest latitudes of Argentina.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], "Humidity (%)", 45, 30)
# Out:
# The r value is:0.36417002547432814

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], "Humidity (%)", -50, 30)
# Out:
# The r value is:0.048196438635507585

# %% [markdown]
# **Discussion about the linear relationship:** For cities in the Northern Hemisphere, the positive slope indicates that as the latitude increases, humidity increases. The absolute value of the r value is 0.36 (between 0.3 and 0.7), which indicates a moderately positive linear relationship meaning that as one variable increases (latitude), the other variable (humidity) tends to increase. However, the correlation isn't strong in this case.
#
# For cities in the Southern Hemisphere, the absolute value of the r value is 0.05 (less than 0.3), which indicates weak or no linear relationship.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], "Cloudiness (%)", 45, 28)
# Out:
# The r value is:0.2202168388864756

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], "Cloudiness (%)", -32, 31)
# Out:
# The r value is:0.2108604899129141

# %% [markdown]
# **Discussion about the linear relationship:** For cities in both the Northern and Southern Hemisphere, the absolute value of the r value is 0.22 and .21 (less than 0.3), respectively, which indicates weak or no linear relationship.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], "Wind Speed (m/s)", 0, 14)
# Out:
# The r value is:0.07408510544816418

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], "Wind Speed (m/s)", -53, 11)
# Out:
# The r value is:-0.24888698731794323

# %% [markdown]
# **Discussion about the linear relationship:** For cities in both the Northern and Southern Hemisphere, the absolute value of the r value is 0.07 and .25 (less than 0.3), respectively, which indicates weak or no linear relationship.
